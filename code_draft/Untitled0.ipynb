# %%
data3['p0'] = deepcopy(data3['p0_new'])
data3['p1'] = deepcopy(data3['p1_new'])
data3['p2'] = deepcopy(data3['p2_new'])
data3['p3'] = deepcopy(data3['p3_new'])

data3.drop(['p0_new','p1_new','p2_new','p3_new'],axis=1)

# %%
data3.to_csv('result.csv')
